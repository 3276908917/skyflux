# %%
import flux
# Out:
# Accessing: //anaconda3/envs/hera/lib/python3.7/site-packages/flux-1!1.1a2-py3.7.egg/flux/
# Missing flux value for: GLEAM J202818-254302 at frequency: 204 MHz.
# Missing flux value for: GLEAM J202818-254302 at frequency: 212 MHz.
# Missing flux value for: GLEAM J202818-254302 at frequency: 220 MHz.
# Missing flux value for: GLEAM J202818-254302 at frequency: 227 MHz.
# Missing spectral index for: GLEAM J202818-254302
# Do not forget that our current approach to J pre-generation is imprecise and mostly wrong.

# %%
flux.demo.brightness_distr()

# %%
flux.demo.brightness_distr(ln=True)

# %%
flux.demo.brightness_distr(data_lim=(2, 100))
