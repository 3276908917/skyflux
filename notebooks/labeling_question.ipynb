# %% [markdown]
# All pictures are for the HERA beam at 150 MHz

# %% [markdown]
# A matrix, absolute value
# ![abs.png](attachment:abs.png)

# %% [markdown]
# A matrix, log10 of absolute value
# ![log10_abs.png](attachment:log10_abs.png)

# %% [markdown]
# A matrix, real part
# ![real.png](attachment:real.png)

# %% [markdown]
# A matrix, imaginary part
# ![imaginary.png](attachment:imaginary.png)

# %% [markdown]
# Using log10 on the imaginary graphs made half of each disappear, for some reason. That is why I do not use the logarithm on these last two pictures.
