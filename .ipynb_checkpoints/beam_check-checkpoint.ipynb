# %%
# %matplotlib notebook
import healpy

# %%
import os
from pyuvdata import UVBeam
from pyuvdata.data import DATA_PATH
import numpy as np
import matplotlib.pyplot as plt
beam = UVBeam()

beam_filenames = [os.path.join(DATA_PATH, f) for f in ['/home/lfinkbeiner/Documents/HERA/HERA_4.9m_E-pattern_151MHz.txt']]

# Most importantly, the hard-code values below are entirely taken from the demo,
    # and do not necessarily reflect your case at all
# It seems a little ridiculous to have to specify frequencies both here and in the file names...
# I do not understand feed polarization. And what is the point of feed version?
beam.read_cst_beam(beam_filenames, beam_type='efield', frequency=[151e6],
    feed_pol='x', rotate_pol=True, telescope_name='HERA',
    feed_name='PAPER_dipole', feed_version='0.1',
    model_name='E-field pattern - Rigging height 4.9m',
    model_version='1.0')

# %%
#beam.efield_to_power()

# %%
beam.interpolation_function = 'az_za_simple'

# %%
beam.beam_type
# Out:
# 'efield'

# %%
beam.to_healpix()

# %%
beam.data_array.shape
# Out:
# (2, 1, 2, 1, 49152)

# %%
healpy.orthview(beam.data_array[1, 0, 0, 0, :], half_sky=True, rot=[0, 90])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-74-0fcd400f2ba2> in <module>
# ----> 1 healpy.orthview(beam.data_array[1, 0, 0, 0, :], half_sky=True, rot=[0, 90])
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
healpy.orthview(beam.data_array[0, 0, 1, 0, :], half_sky=True, rot=[0, 90])
# Out:
# <img src="data:image/png;base64,..." width="850">

# %%
healpy.orthview(beam.data_array[1, 0, 1, 0, :], half_sky=True, rot=[0, 90])
# Out:
# <img src="data:image/png;base64,..." width="850">

# %%
healpy.orthview(beam.data_array[0, 0, 0, 0, :], half_sky=True, rot=[0, 90])
# Out:
# <img src="data:image/png;base64,..." width="850">

# %%
beam.efield_to_pstokes()

# %%
beam.data_array.shape
# Out:
# (1, 1, 4, 1, 181, 360)

# %%
beam.data_array[0, 0, 0, 0, :]
# Out:
# array([[8355.78811505+0.j, 8356.504025  +0.j, 8356.8257    +0.j, ...,
#         8356.760325  +0.j, 8356.832081  +0.j, 8356.507216  +0.j],
#        [8129.74430023+0.j, 8129.5153045 +0.j, 8129.726325  +0.j, ...,
#         8129.496925  +0.j, 8129.7357685 +0.j, 8129.520029  +0.j],
#        [7482.50507695+0.j, 7482.1819025 +0.j, 7482.0945245 +0.j, ...,
#         7482.2620185 +0.j, 7482.1066265 +0.j, 7482.1879625 +0.j],
#        ...,
#        [   9.680028  +0.j,    9.68292761+0.j,    9.68235408+0.j, ...,
#            9.68183581+0.j,    9.68254633+0.j,    9.6830293 +0.j],
#        [  11.30652413+0.j,   11.30321435+0.j,   11.30679519+0.j, ...,
#           11.30398086+0.j,   11.30691209+0.j,   11.30327409+0.j],
#        [  11.89560102+0.j,   11.89232443+0.j,   11.89628109+0.j, ...,
#           11.89371625+0.j,   11.89630516+0.j,   11.89232924+0.j]])

# %%
healpy.orthview(beam.data_array[0, 0, 3, 0, :], half_sky=True, rot=[0, 90])
# Out:
# <img src="data:image/png;base64,..." width="850">

# %%
healpy.orthview(beam.data_array[0, 0, 2, 0, :], half_sky=True, rot=[0, 90])
# Out:
# <img src="data:image/png;base64,..." width="1416.6666666666667">

# %%
healpy.orthview(beam.data_array[0, 0, 1, 0, :], half_sky=True, rot=[0, 90])
# Out:
# <img src="data:image/png;base64,..." width="1416.6666666666667">
